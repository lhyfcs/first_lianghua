# %%
import torch
import torch.nn.functional as F
import torch.nn as nn
from torch.autograd import Variable
import matplotlib.pyplot as plt
import torchvision
import torch.utils.data as Data
import numpy as np
import gym

# %%
torch.manual_seed(1)

N_SAMPLES = 20
N_HIDDEN = 300
x = torch.unsqueeze(torch.linspace(-1, 1, N_SAMPLES), 1)
y = x + 0.3 * torch.normal(torch.zeros(N_SAMPLES, 1), torch.ones(N_SAMPLES, 1))

test_x = torch.unsqueeze(torch.linspace(-1, 1, N_SAMPLES), 1)
test_y = test_x + 0.3 * torch.normal(torch.zeros(N_SAMPLES, 1), torch.ones(N_SAMPLES, 1))

plt.scatter(x.data.numpy(), y.data.numpy(), c='magenta', s=50, alpha=0.5, label='p1')
plt.scatter(test_x.data.numpy(), test_y.data.numpy(), c='cyan', s=50, alpha=0.5, label='p2')
plt.legend(loc='upper left')
plt.ylim((-2.5, 2.5))
plt.show()

# %%
net_overfitting = torch.nn.Sequential(
    nn.Linear(1, N_HIDDEN),
    nn.ReLU(),
    torch.nn.Linear(N_HIDDEN, N_HIDDEN),
    nn.ReLU(),
    nn.Linear(N_HIDDEN, 1)
)

net_dropout = nn.Sequential(
    nn.Linear(1, N_HIDDEN),
    nn.Dropout(0.5),
    nn.ReLU(),
    torch.nn.Linear(N_HIDDEN, N_HIDDEN),
    nn.Dropout(0.5),
    nn.ReLU(),
    nn.Linear(N_HIDDEN, 1)
)
print(net_overfitting)
print(net_dropout)

opt_ofit = torch.optim.Adam(net_overfitting.parameters(), lr=0.01)
opt_drop = torch.optim.Adam(net_dropout.parameters(), lr=0.01)
loss_func = nn.MSELoss()
# Out:
# Sequential(
#   (0): Linear(in_features=1, out_features=300, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=300, out_features=300, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=300, out_features=1, bias=True)
# )
# Sequential(
#   (0): Linear(in_features=1, out_features=300, bias=True)
#   (1): Dropout(p=0.5, inplace=False)
#   (2): ReLU()
#   (3): Linear(in_features=300, out_features=300, bias=True)
#   (4): Dropout(p=0.5, inplace=False)
#   (5): ReLU()
#   (6): Linear(in_features=300, out_features=1, bias=True)
# )

# %%
for t in range(500):

    pred_ofit = net_overfitting(x)
    pred_drop = net_dropout(x)
    loss_ofit = loss_func(pred_ofit, y)
    loss_drop = loss_func(pred_drop, y)
    
    opt_ofit.zero_grad()
    loss_ofit.backward()
    opt_ofit.step()
    opt_drop.zero_grad()
    loss_drop.backward()
    opt_drop.step()
    
    if t % 10 == 0:
        net_dropout.eval()
        net_overfitting.eval()
        
        plt.cla()
        test_pred_ofit = net_overfitting(test_x)
        test_pred_drop = net_dropout(test_x)
        
        plt.scatter(x.data.numpy(), y.data.numpy(), c='magenta', s=50, alpha=0.3, label='train')
        plt.scatter(test_x.data.numpy(), test_y.data.numpy(), c='cyan', s=50, alpha=0.3, label='test')
        plt.plot(test_x.data.numpy(), test_pred_ofit.data.numpy(), 'r-', lw=3, label='overfitting')
        plt.plot(test_x.data.numpy(), test_pred_drop.data.numpy(), 'b--', lw=3, label='dropout(50%)')
        plt.text(0, -1.2, 'overfitting loss=%.4f' % loss_func(test_pred_ofit, test_y).item(), fontdict={'size': 20, 'color':  'red'})
        plt.text(0, -1.5, 'dropout loss=%.4f' % loss_func(test_pred_drop, test_y).item(), fontdict={'size': 20, 'color': 'blue'})
        plt.legend(loc='upper left')
        plt.ylim((-2.5, 2.5))
        plt.pause(0.1)
        
        net_dropout.train()
        net_overfitting.train()
